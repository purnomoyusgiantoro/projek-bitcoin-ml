# %% [markdown]
# <a href="https://colab.research.google.com/github/purnomoyusgiantoro/projek-bitcoin-ml/blob/main/bitcoin_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/btcusd_1-min_data.csv')
df.head()
# Out:
#       Timestamp  Open  High   Low  Close  Volume
# 0  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 1  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 2  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 3  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 4  1.325412e+09  4.58  4.58  4.58   4.58     0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032856 entries, 0 to 1032855
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Timestamp  1032856 non-null  float64
#  1   Open       1032855 non-null  float64
#  2   High       1032855 non-null  float64
#  3   Low        1032855 non-null  float64
#  4   Close      1032855 non-null  float64
#  5   Volume     1032855 non-null  float64
# dtypes: float64(6)
# memory usage: 47.3 MB

# %%
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(), annot=True,linewidths= 0.5, annot_kws={'fontsize': 10}, ax=ax)
plt.show()

# %%
df.plot(kind='scatter', x='High',y='Low',alpha = 0.5,color = 'red')
plt.xlabel('High')
plt.ylabel('Low')
plt.title('High Low Scatter Plot')
plt.show()

# %%
df.High.plot(kind='hist',bins= 50,figsize=(10,10))
plt.show()

# %%
print(df.isna().sum())
print((df == float('inf')).sum())
print((df == float('-inf')).sum())
# Out:
# Timestamp    0
# Open         1
# High         1
# Low          1
# Close        1
# Volume       1
# dtype: int64
# Timestamp    0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# dtype: int64
# Timestamp    0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# dtype: int64

# %%
df.head()
# Out:
#       Timestamp  Open  High   Low  Close  Volume
# 0  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 1  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 2  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 3  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 4  1.325412e+09  4.58  4.58  4.58   4.58     0.0

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'],unit='s')
df.set_index('Timestamp',inplace=True)

# %%
df.sample(10)
# Out:
#                        Open    High     Low   Close     Volume
# Timestamp
# 2013-09-20 20:13:00  124.48  124.48  124.48  124.48   0.000000
# 2013-07-20 18:18:00   87.07   87.07   87.07   87.07   0.000000
# 2012-06-16 18:11:00    6.50    6.50    6.50    6.50   0.000000
# 2013-07-01 19:09:00   87.55   87.55   87.55   87.55  24.557396
# 2012-05-13 15:06:00    4.95    4.95    4.95    4.95   0.000000
# 2012-11-15 08:32:00   10.96   10.96   10.96   10.96   0.000000
# 2013-10-27 02:43:00  179.15  179.15  179.15  179.15  25.882321
# 2013-06-21 02:31:00  104.00  104.00  103.99  103.99  12.570000
# 2013-05-08 10:58:00  110.97  110.97  110.97  110.97   2.004235
# 2012-11-05 11:17:00   10.50   10.50   10.50   10.50   0.000000
